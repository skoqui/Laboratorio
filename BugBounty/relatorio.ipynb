# %% [markdown]
# # **CTF Write-up — [Nome do Desafio]**
#
# **Plataforma:** TryHackMe / Hack The Box / Outra
# **Dificuldade:** Easy / Medium / Hard
# **Categoria:** Web / Linux / Forensics / OSINT / Crypto
# **Autor:** Luis Scoqui
# **Data:** YYYY-MM-DD

# %% [markdown]
# ## **Objetivo**
#
# Explorar a máquina/aplicação para obter as flags solicitadas,
# aplicando técnicas de enumeração, exploração e escalonamento de privilégios.

# %% [markdown]
# ## **Informações Iniciais**
#
# - IP alvo: `10.10.10.X`
# - Sistema Operacional: Linux / Windows
# - Ferramentas principais:
#   - nmap
#   - gobuster
#   - netcat

# %%
nmap -sC -sV -p- 10.10.10.X

# %% [markdown]
# ## **Análise**
#
# - Porta 22 (SSH) aberta
# - Porta 80 (HTTP) ativa com possível aplicação web
# - Nenhum WAF detectado

# %% [markdown]
# ## **Exploração**
#
# Durante a enumeração web foi identificado um endpoint vulnerável
# a **[tipo de vulnerabilidade]**, permitindo acesso inicial ao sistema.

# %%
curl http://10.10.10.X/vulnerable?cmd=id

# %% [markdown]
# ## **User Flag**

# %%
THM{user_flag_here}

# %% [markdown]
# ## **Privilege Escalation**
#
# O usuário possuía permissão sudo para executar
# um binário vulnerável, permitindo acesso root.

# %% [markdown]
# ## **Root Flag**

# %%
THM{root_flag_here}

# %% [markdown]
# ## **Conclusão**
#
# Este desafio reforçou conceitos de:
# - Enumeração inicial
# - Análise de serviços
# - Escalonamento de privilégios
#
# Desafio útil para consolidar fundamentos de segurança ofensiva.
